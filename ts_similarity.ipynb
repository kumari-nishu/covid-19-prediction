# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from scipy.stats import pearsonr
import math
from scipy import spatial
from pmdarima import auto_arima
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from math import sqrt
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# %%
#confirmed = pd.read_csv('time_series_covid19_confirmed_global.csv')
# confirmed = pd.read_csv('time_series_covid19_deaths_global.csv')
# recovered = pd.read_csv('time_series_covid19_recovered_global.csv')

# latest
confirmed = pd.read_csv('time_series_covid19_confirmed_global.csv')
#confirmed= pd.read_csv('deaths_global_latest.csv')

# %% [markdown]
# # Util

# %%
def scorer(y_pred, y_test):
    return np.sum([(np.log10(x) - np.log10(y))**2 for x, y in zip(y_pred, y_test) if x>1 and y>100])

# %%
def evaluate(sorted_combined):
    n = len(sorted_combined[0][2])
    scores = []
    for day in range(n):
        y_real = []
        y_pred = []
        for a in sorted_combined:
            
            y_real = y_real + [a[2]['cases'].values[day]]
            y_pred = y_pred + [a[3]['Prediction'].values[day]]

        y_pred = [int(np.ceil(x)) for x in y_pred]
        sc = scorer(y_pred, y_real)
        print(day, sc)
        scores.append(sc)
    return scores, y_pred, y_real

# %%
def evaluate_ensemble(sorted_combined, sorted_combined1):
    n = len(sorted_combined[0][2])
    scores = []
    for day in range(n):
        y_real = []
        y_pred = []
        y_pred1 = []
        for i in range(len(sorted_combined)):
            a = sorted_combined[i]
            b = sorted_combined1[i]
            y_real = y_real + [a[2]['cases'].values[day]]
            y_pred = y_pred + [a[3]['Prediction'].values[day]]
            y_pred1 = y_pred1 + [b[3]['Prediction'].values[day]]

        y_pred_ensembled = [int(np.ceil((x+x1)/2.0) ) for x,x1 in zip(y_pred, y_pred1)]
        sc = scorer(y_pred_ensembled, y_real)
        print(day, sc)
        scores.append(sc)
    return scores, y_pred_ensembled,y_pred, y_pred1,  y_real

# %% [markdown]
# # Auto Arima

# %%
a=10
columns = confirmed.columns[4:]
df = pd.DataFrame({'cases':confirmed.iloc[a].values[4:]})
df.index = pd.to_datetime(columns)
train = df
valid = df[-8:]
print(train['cases'][-2])
# Out:
# 28

# %%
def my_arima_model(index, train, valid, do_plot=0):
    if train['cases'][-1]==train['cases'][-2] and train['cases'][-2]==train['cases'][-3]:
        forecast = [train['cases'][-1]]*(len(valid))
        print('......', forecast)
    else:
        model = auto_arima(train, trace=True, error_action='ignore', suppress_warnings=True, information_criterion='bic')
        model.fit(train)
        forecast = model.predict(n_periods=len(valid))
        print('---------', forecast)

    forecast = pd.DataFrame(forecast,index = valid.index,columns=['Prediction'])
    rms = sqrt(mean_squared_error(valid,forecast))
    print(index, rms)
    #plot the predictions for validation set
    if do_plot==1:
        plt.plot(train, label='Train')
        plt.plot(valid, label='Valid')
        plt.plot(forecast, label='Prediction')
        plt.legend()
        plt.show()
    return rms, forecast

# %%
combined = []
columns = confirmed.columns[4:]
for a in range(len(confirmed)):
    df = pd.DataFrame({'cases':confirmed.iloc[a].values[4:]})
    df.index = pd.to_datetime(columns)
    train = df
    valid = df[-8:]
    rms, forecast = my_arima_model(a, train, valid)
    current = [rms, a, valid, forecast, train]
    combined.append(current)
# Out:
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=715.100, BIC=730.166, Time=0.111 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=767.877, BIC=772.899, Time=0.006 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=721.833, BIC=729.366, Time=0.018 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=720.911, BIC=728.444, Time=0.027 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=766.327, BIC=768.837, Time=0.006 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=719.212, BIC=729.255, Time=0.040 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=724.765, BIC=734.809, Time=0.053 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=713.147, BIC=725.701, Time=0.072 seconds
# Fit ARIMA: (1, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=715.102, BIC=730.167, Time=0.124 seconds
# Fit ARIMA: (0, 2, 3)x(0, 0, 0, 0) (constant=True); AIC
seconds
# Fit ARIMA: (3, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=253.476, BIC=268.542, Time=0.059 seconds
# Fit ARIMA: (3, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=257.231, BIC=269.786, Time=0.040 seconds
# Fit ARIMA: (3, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=250.634, BIC=268.210, Time=0.086 seconds
# Total fit time: 0.695 seconds
# --------- [24.69498684 25.39930952 26.11296805 26.83596242 27.56829264 28.3099587
#  29.0609606  29.82129836]
# 5 4.207146301703812
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=927.871, BIC=942.936, Time=0.124 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=999.789, BIC=1004.811, Time=0.006 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=961.201, BIC=968.733, Time=0.023 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=939.734, BIC=947.267, Time=0.036 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=998.070, BIC=1000.581, Time=0.009 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=926.095, BIC=938.649, Time=0.120 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=925.524, BIC=935.567, Time=0.058 seconds
# Fit ARIMA: (0, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=926.480, BIC=939.035, Time=0.108 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=932.419, BIC=942.462, Time=0.062 seconds
# Fit ARIMA: (1, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=928.033, BIC=943.098, Time=0.241 seconds
# Near non-invertible roots for order (1, 2, 3)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Total fit time: 0.793 seconds
# --------- [3456.56754367 3594.50613916 3733.9440563  3874.88129509 4017.31785553
#  4161.25373762 4306.68894136 4453.62346675]
# 6 1030.2718892015
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=721.000, BIC=736.066, Time=0.060 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=749.831, BIC=754.852, Time=0.008 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=730.861, BIC=738.393, Time=0.025 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=719.066, BIC=726.598, Time=0.025 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=747.960, BIC=750.471, Time=0.008 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=721.021, BIC=731.064, Time=0.044 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=721.010, BIC=731.054, Time=0.041 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=721.291, BIC=733.845, Time=0.060 seconds
# Total fit time: 0.277 seconds
# --------- [1580.14924407 1637.93234747 1696.3493102  1755.40013227 1815.08481366
#  1875.40335439 1936.35575445 1997.94201384]
# 7 457.8407082439625
# ...... [104, 104, 104, 104, 104, 104, 104, 104]
# 8 0.7071067811865476
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=914.438, BIC=929.503, Time=0.120 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=962.453, BIC=967.475, Time=0.007 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=926.244, BIC=933.776, Time=0.025 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=923.436, BIC=930.969, Time=0.030 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=960.453, BIC=962.964, Time=0.005 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=912.293, BIC=924.847, Time=0.093 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=911.469, BIC=921.512, Time=0.045 seconds
# Fit ARIMA: (0, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=912.389, BIC=924.943, Time=0.052 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=918.313, BIC=928.356, Time=0.035 seconds
# Fit ARIMA: (1, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=914.277, BIC=929.343, Time=0.153 seconds
# Total fit time: 0.571 seconds
# --------- [2976.75012346 2977.71561789 2978.69340437 2979.68348289 2980.68585347
#  2981.70051609 2982.72747077 2983.76671749]
# 9 38.80045504004948
# ...... [28, 28, 28, 28, 28, 28, 28, 28]
# 10 0.0
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=651.421, BIC=666.486, Time=0.071 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=662.474, BIC=667.496, Time=0.006 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=660.431, BIC=667.964, Time=0.020 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=656.392, BIC=663.925, Time=0.021 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=660.474, BIC=662.985, Time=0.006 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=662.527, BIC=672.571, Time=0.090 seconds
# Near non-invertible roots for order (1, 2, 1)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Total fit time: 0.219 seconds
# --------- [1028. 1030. 1032. 1034. 1036. 1038. 1040. 1042.]
# 11 18.604434955130902
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=653.344, BIC=668.409, Time=0.210 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=702.460, BIC=707.481, Time=0.008 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=661.249, BIC=668.782, Time=0.024 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=655.590, BIC=663.123, Time=0.025 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=700.460, BIC=702.970, Time=0.008 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=650.825, BIC=660.868, Time=0.034 seconds
# Fit ARIMA: (2, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=652.173, BIC=664.727, Time=0.036 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=651.167, BIC=663.722, Time=0.052 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=649.311, BIC=659.355, Time=0.042 seconds
# Fit ARIMA: (0, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=651.188, BIC=663.742, Time=0.060 seconds
# Fit ARIMA: (1, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=653.055, BIC=668.120, Time=0.128 seconds
# Total fit time: 0.634 seconds
# --------- [439.04161438 439.80976694 440.58621328 441.3709534  442.1639873
#  442.96531497 443.77493642 444.59285165]
# 12 6.074054131332555
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC
seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=1717.546, BIC=1725.079, Time=0.097 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=1769.564, BIC=1772.074, Time=0.011 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=1718.929, BIC=1728.972, Time=0.086 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=1718.755, BIC=1728.798, Time=0.239 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=1720.725, BIC=1733.279, Time=0.421 seconds
# Total fit time: 1.073 seconds
# --------- [160887.81438127 164794.11550218 168744.90336274 172740.17796294
#  176779.93930278 180864.18738228 184992.92220141 189166.14376019]
# 116 23775.22112914913
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=555.412, BIC=570.478, Time=0.182 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=617.498, BIC=622.519, Time=0.014 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=584.875, BIC=592.407, Time=0.040 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=555.590, BIC=563.122, Time=0.082 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=615.498, BIC=618.009, Time=0.013 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=553.852, BIC=563.896, Time=0.202 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=543.883, BIC=553.926, Time=0.101 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=553.438, BIC=565.992, Time=0.149 seconds
# Fit ARIMA: (0, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=536.772, BIC=549.326, Time=0.139 seconds
# Fit ARIMA: (1, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=538.416, BIC=553.481, Time=0.537 seconds
# Fit ARIMA: (0, 2, 4)x(0, 0, 0, 0) (constant=True); AIC=537.415, BIC=552.480, Time=0.180 seconds
# Fit ARIMA: (1, 2, 4)x(0, 0, 0, 0) (constant=True); AIC=529.345, BIC=546.921, Time=0.214 seconds
# Fit ARIMA: (2, 2, 4)x(0, 0, 0, 0) (constant=True); AIC=526.526, BIC=546.613, Time=0.600 seconds
# Near non-invertible roots for order (2, 2, 4)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.991)
# Fit ARIMA: (1, 2, 5)x(0, 0, 0, 0) (constant=True); AIC=526.867, BIC=546.954, Time=0.391 seconds
# Fit ARIMA: (0, 2, 5)x(0, 0, 0, 0) (constant=True); AIC=525.993, BIC=543.569, Time=0.309 seconds
# Total fit time: 3.170 seconds
# --------- [181.33027795 201.59921504 215.69013947 227.82828836 241.88332751
#  256.08802923 270.44239351 284.94642034]
# 117 108.65006747069458
# ...... [10, 10, 10, 10, 10, 10, 10, 10]
# 118 0.6123724356957945
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=552.310, BIC=567.375, Time=0.462 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=601.468, BIC=606.490, Time=0.015 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=557.297, BIC=564.829, Time=0.046 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=556.031, BIC=563.564, Time=0.060 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=599.490, BIC=602.000, Time=0.013 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=554.505, BIC=564.548, Time=0.057 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=556.556, BIC=566.599, Time=0.072 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=554.467, BIC=567.021, Time=0.096 seconds
# Total fit time: 0.833 seconds
# --------- [436.83085266 448.79545441 460.89380527 473.12590522 485.49175426
#  497.99135241 510.62469965 523.39179599]
# 119 86.15259397089467
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=1446.543, BIC=1461.608, Time=0.469 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=1461.898, BIC=1466.920, Time=0.012 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=1463.253, BIC=1470.786, Time=0.024 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=1463.217, BIC=1470.749, Time=0.029 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=1460.025, BIC=1462.536, Time=0.011 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=1463.913, BIC=1476.467, Time=0.301 seconds
# Fit ARIMA: (2, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=1463.469, BIC=1476.023, Time=0.183 seconds
# Fit ARIMA: (3, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=1444.778, BIC=1462.354, Time=0.398 seconds
# Fit ARIMA: (2, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=1448.360, BIC=1465.936, Time=0.642 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=1462.439, BIC=1472.483, Time=0.221 seconds
# Fit ARIMA: (1, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=1463.464, BIC=1478.530, Time=0.229 seconds
# Fit ARIMA: (3, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=1460.585, BIC=1475.650, Time=0.207 seconds
# Fit ARIMA: (3, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=1454.401, BIC=1474.488, Time=0.544 seconds
# Near non-invertible roots for order (3, 2, 3)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Total fit time: 3.290 seconds
# --------- [155578.51407875 157646.03180022 159258.12056304 160642.10235
#  162148.64745612 164008.71394116 166191.5224874  168448.43932825]
# 120 15917.24263562381
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=899.084, BIC=914.149, Time=0.345 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=950.264, BIC=955.286, Time=0.019 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=941.327, BIC=948.860, Time=0.048 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=904.283, BIC=911.816, Time=0.069 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=948.264, BIC=950.775, Time=0.011 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=905.989, BIC=916.033, Time=0.096 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=905.672, BIC=915.715, Time=0.153 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=905.099, BIC=917.653, Time=0.274 seconds
# Near non-invertible roots for order (1, 2, 2)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Total fit time: 1.026 seconds
# --------- [1207.99692998 1262.65407404 1317.97143218 1373.94900441 1430.58679071
#  1487.8847911  1545.84300556 1604.46143411]
# 121 468.85861149132523
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=858.139, BIC=873.204, Time=0.186 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=907.090, BIC=912.111, Time=0.014 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=860.732, BIC=868.265, Time=0.045 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=857.367, BIC=864.899, Time=0.058 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=905.117, BIC=907.628, Time=0.013 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=854.990, BIC=865.033, Time=0.108 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=856.487, BIC=866.530, Time=0.099 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=856.376, BIC=868.931, Time=0.216 seconds
# Total fit time: 0.749 seconds
# --------- [2509.13223249 2555.78167236 2602.9483196  2650.63217422 2698.83323621
#  2747.55150557 2796.7869823  2846.53966641]
# 122 376.4670602764847
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=602.228, BIC=617.293, Time=0.414 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=627.678, BIC=632.700, Time=0.013 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=620.604, BIC=628.137, Time=0.036 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=608.358, BIC=615.891, Time=0.042 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=626.590, BIC=629.100, Time=0.018 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=610.007, BIC=620.050, Time=0.075 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=608.535, BIC=618.578, Time=0.139 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=612.303, BIC=624.857, Time=0.186 seconds
# Total fit time: 0.934 seconds
# --------- [417.51909126 451.41314045 485.68214756 520.32611261 555.34503558
#  590.73891648 626.50775532 662.65155207]
# 123 267.0845614825574
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=668.295, BIC=683.360, Time=0.215 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=699.584, BIC=704.606, Time=0.013 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=664.856, BIC=672.389, Time=0.036 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=670.446, BIC=677.979, Time=0.054 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=698.496, BIC=701.007, Time=0.012 seconds
# Fit ARIMA: (2, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=666.850, BIC=676.894, Time=0.070 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=666.841, BIC=676.884, Time=0.059 seconds
# Fit ARIMA: (2, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=668.196, BIC=680.750, Time=0.120 seconds
# Total fit time: 0.589 seconds
# --------- [ 948.02407644 1044.51433466 1136.40883601 1232.62437385 1327.88213211
#  1425.30721395 1523.04953222 1622.20435395]
# 124 670.1094174316356
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=447.769, BIC=462.834, Time=0.382 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=508.539, BIC=513.561, Time=0.014 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=492.358, BIC=499.891, Time=0.052 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=446.283, BIC=453.815, Time=0.125 seconds
# Near non-invertible roots for order (0, 2, 1)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=506.546, BIC=509.057, Time=0.016 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=449.621, BIC=462.176, Time=0.298 seconds
# Near non-invertible roots for order (1, 2, 2)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: (2, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=445.771, BIC=458.326, Time=0.241 seconds
# Near non-invertible roots for order (2, 2, 1)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: (3, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=449.712, BIC=467.288, Time=0.456 seconds
# Near non-invertible roots for order (3, 2, 2)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: (2, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=449.503, BIC=467.079, Time=0.609 seconds
# Near non-invertible roots for order (2, 2, 3)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=448.009, BIC=458.053, Time=0.355 seconds
# Near non-invertible roots for order (1, 2, 1)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: (1, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=447.537, BIC=462.602, Time=0.431 seconds
# Near non-invertible roots for order (1, 2, 3)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: (3, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=447.770, BIC=462.836, Time=0.843 seconds
# Near non-invertible roots for order (3, 2, 1)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: (3, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=451.492, BIC=471.579, Time=0.592 seconds
# Near non-invertible roots for order (3, 2, 3)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.993)
# Total fit time: 4.428 seconds
# --------- [72.25135653 74.53476609 76.85022869 79.19774432 81.57731299 83.98893469
#  86.43260943 88.9083372 ]
# 125 16.422642568014325
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=353.955, BIC=369.021, Time=0.128 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=410.665, BIC=415.686, Time=0.013 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=383.104, BIC=390.636, Time=0.033 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=356.343, BIC=363.876, Time=0.081 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=408.879, BIC=411.390, Time=0.013 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=355.289, BIC=365.332, Time=0.079 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=353.866, BIC=363.910, Time=0.108 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=355.674, BIC=368.228, Time=0.149 seconds
# Total fit time: 0.612 seconds
# --------- [ 76.00310555  80.05327976  84.15052265  88.29483421  92.48621445
#   96.72466335 101.01018092 105.34276717]
# 126 37.72655790934441
# ...... [9, 9, 9, 9, 9, 9, 9, 9]
# 127 0.7071067811865476
# Performing stepwise search to minimize bic
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=642.479, BIC=657.544, Time=0.209 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=696.971, BIC=701.993, Time=0.013 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=657.709, BIC=665.242, Time=0.034 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=643.136, BIC=650.669, Time=0.048 seconds
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=False); AIC=694.979, BIC=697.490, Time=0.013 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=641.515, BIC=651.559, Time=0.066 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=641.615, BIC=651.658, Time=0.060 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=643.501, BIC=656.055, Time=0.115 seconds
# Total fit time: 0.569 seconds
# --------- [532.20429343 545.55802935 559.06120774 572.71382862 586.51589198
#  600.46739781 614.56834613 628.81873693]
# 128 105.40820305739913
# Performing stepwise search to minimize bic

# %%
score, y_pred, y_real = evaluate(combined)
print("Score ",score)
print("Prediction, Actual")
arima_pred_df = pd.DataFrame({"Actual": y_real, "Prediction":y_pred})
#arima_pred_df.to_csv("21_april_deaths_arima_pred_df.csv", index=False)
#arima_pred_df.head()

# %% [markdown]
# # Holt winter

# %%
def my_arima_model(index, train, valid, do_plot=0):
    if train['cases'][-1]==train['cases'][-2] and train['cases'][-2]==train['cases'][-3]:
        pred1 = [train['cases'][-1]]*(len(valid))
        pred2 = [train['cases'][-1]]*(len(valid))
        print('......', forecast)
    else:
        model1 = ExponentialSmoothing(np.asarray(train['cases']), trend="add", seasonal="add", seasonal_periods=7)
        model2 = ExponentialSmoothing(np.asarray(train['cases']), trend="add", seasonal="add", seasonal_periods=7, damped=True)
        fit1 = model1.fit()
        pred1 = fit1.forecast(len(valid))
        fit2 = model2.fit()
        pred2 = fit2.forecast(len(valid))
        
    forecast1 = pd.DataFrame(pred1,index = valid.index,columns=['Prediction'])
    rms1 = sqrt(mean_squared_error(valid,forecast1))
    forecast2 = pd.DataFrame(pred2,index = valid.index,columns=['Prediction'])
    rms2 = sqrt(mean_squared_error(valid,forecast2))
    
    print(index, rms1, rms2)
    
    #plot the predictions for validation set
    if do_plot==1:
        plt.plot(train, label='Train')
        plt.plot(valid, label='Valid')
        plt.plot(forecast, label='Prediction')
        plt.legend()
        plt.show()
    return rms1, forecast1, rms2, forecast2

# %%
combined1 = []
combined2 = []
columns = confirmed.columns[4:]
for a in range(len(confirmed)):
    df = pd.DataFrame({'cases':confirmed.iloc[a].values[4:], 'date':pd.to_datetime(columns)}).set_index('date')
    #df.index = pd.to_datetime(columns)
    train = df
    valid = df[-8:]
    rms1, forecast1, rms2, forecast2 = my_arima_model(a, train, valid)
    current1 = [rms1, a, valid, forecast1, train]
    combined1.append(current1)
    current2 = [rms2, a, valid, forecast2, train]
    combined2.append(current2)

# %%
score, y_pred, y_real = evaluate(combined1)
print("Score ",score)
print("Prediction, Actual")
arima_pred_df = pd.DataFrame({"Actual": y_real, "Prediction":y_pred})
#arima_pred_df.to_csv("22_april_cases_holt_pred_df.csv", index=False)
#arima_pred_df.head()

# %%
score, y_pred_7thday, y_pred, y_pred1, y_real  = evaluate_ensemble(combined, combined1)

# %% [markdown]
# # Ensembled

# %%
ensembled_Results = pd.DataFrame({'7th_yReal': y_real, '7th_yArima': y_pred, '7th_yHolt': y_pred1, '7th_yEnsembled': y_pred_7thday})
ensembled_Results.to_csv("latest_ensembled_cases.csv", index=False)
